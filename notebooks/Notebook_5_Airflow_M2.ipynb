# %% [markdown]
# # Notebook 5 — Projet final (M2)
#
# Construire un pipeline Airflow complet :
# 1) Ingestion (API/fichiers)
# 2) Transformations
# 3) Data Quality
# 4) Load DB
# 5) Notification
#
# Contraintes : robustesse, idempotence, paramétrage, doc.

# %% [markdown]
# ## Bonus
#
# - TaskFlow API
# - Dynamic task mapping
# - CI tests DagBag
