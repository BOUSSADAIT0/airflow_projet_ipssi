# %% [markdown]
# # Notebook 2 — DAGs avancés : XCom, Variables, Templates
#
# **Objectifs**
# - Passer des données entre tasks (XCom)
# - Paramétrer via Variables/Connections
# - Utiliser les templates Jinja

# %% [markdown]
# ## XCom
#
# DAG : `dags/d2_xcom_pipeline.py`
# - Lance-le
# - Consulte les XCom via l’UI

# %%
from pathlib import Path
print(Path("../dags/d2_xcom_pipeline.py").read_text(encoding="utf-8")[:1100])

# %% [markdown]
# ## Exercices
#
# 1) Variable `WELCOME_MSG` et utilisation dans une task
# 2) Réécrire le pipeline avec TaskFlow API (`@task`)
# 3) Ajouter un contrôle simple (assert) en task dédiée
