# %% [markdown]
# # Notebook 4 — Industrialisation : SLA, alerting, tests
#
# **Objectifs**
# - SLA & callbacks
# - Bonnes pratiques prod
# - Introduction tests

# %% [markdown]
# ## SLA
#
# DAG : `dags/d4_sla_and_retries.py`
# - Lance-le
# - Observe le callback SLA dans les logs

# %%
from pathlib import Path
print(Path("../dags/d4_sla_and_retries.py").read_text(encoding="utf-8")[:1100])

# %% [markdown]
# ## Exemple de smoke test (local, venv)
#
# ```python
# from airflow.models import DagBag
# dagbag = DagBag(dag_folder="../dags", include_examples=False)
# assert len(dagbag.import_errors) == 0
# ```

# %% [markdown]
# ## Exercices
#
# 1) Ajouter `on_failure_callback`
# 2) Normaliser tags
# 3) Refactoriser en fonctions réutilisables
